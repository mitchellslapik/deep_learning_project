# %%
import torch
import numpy as np
#layer1 = torch.load('1_layers_train_acc');
layer2 = np.load('train_accuracy_color2.npy');
layer3 = np.load('train_accuracy_color3.npy');
layer4 = np.load('train_accuracy_color4.npy');
layer5 = np.load('train_accuracy_color5.npy');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("hls", 8)

fig, ax = plt.subplots() 

#ax.plot(range(1, 11), layer1, color = rainbow[6],  linewidth=4)
ax.plot(range(1, 11), layer2, color = rainbow[5],  linewidth=4,)
ax.plot(range(1, 11), layer3, color = rainbow[3],  linewidth=4,)
ax.plot(range(1, 11), layer4, color = rainbow[1], linewidth=4,)
ax.plot(range(1, 11), layer5, color = rainbow[0],  linewidth=4,)

ax.set_xlabel('Epoch', fontname="Arial", fontsize = 20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize = 20)
ax.set_title('Training Accuracy', fontname="Arial", fontsize = 25, fontweight="bold")



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.ylim(.4, .7)
    
plt.show()

# %%
import torch
import numpy as np
#layer1 = torch.load('1_layers_train_acc');
layer2 = np.load('test_accuracy_color2.npy');
layer3 = np.load('test_accuracy_color3.npy');
layer4 = np.load('test_accuracy_color4.npy');
layer5 = np.load('test_accuracy_color5.npy');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("hls", 8)

fig, ax = plt.subplots() 

#ax.plot(range(1, 11), layer1, color = rainbow[6],  linewidth=4)
ax.plot(range(1, 11), layer2, color = rainbow[5],  linewidth=4,)
ax.plot(range(1, 11), layer3, color = rainbow[3],  linewidth=4,)
ax.plot(range(1, 11), layer4, color = rainbow[1], linewidth=4,)
ax.plot(range(1, 11), layer5, color = rainbow[0],  linewidth=4,)

ax.set_xlabel('Epoch', fontname="Arial", fontsize = 20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize = 20)
ax.set_title('Test Accuracy', fontname="Arial", fontsize = 25, fontweight="bold")



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.ylim(.4, .7)
    
plt.show()

# %%
import torch
import numpy as np
#layer1 = torch.load('1_layers_train_acc');
layer2 = np.load('train_loss_color2.npy');
layer3 = np.load('train_loss_color3.npy');
layer4 = np.load('train_loss_color4.npy');
layer5 = np.load('train_loss_color5.npy');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("hls", 8)

fig, ax = plt.subplots() 

#ax.plot(range(1, 11), layer1, color = rainbow[6],  linewidth=4)
ax.plot(range(1, 11), layer2, color = rainbow[5],  linewidth=4,)
ax.plot(range(1, 11), layer3, color = rainbow[3],  linewidth=4,)
ax.plot(range(1, 11), layer4, color = rainbow[1], linewidth=4,)
ax.plot(range(1, 11), layer5, color = rainbow[0],  linewidth=4,)

ax.set_xlabel('Epoch', fontname="Arial", fontsize = 20)
ax.set_ylabel('Cross-Entropy', fontname="Arial", fontsize = 20)
ax.set_title('Training Loss', fontname="Arial", fontsize = 25, fontweight="bold")



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.ylim(.8, 1.6)
    
plt.show()

# %%
import torch
import numpy as np
#layer1 = torch.load('1_layers_train_acc');
layer2 = np.load('test_loss_color2.npy');
layer3 = np.load('test_loss_color3.npy');
layer4 = np.load('test_loss_color4.npy');
layer5 = np.load('test_loss_color5.npy');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("hls", 8)

fig, ax = plt.subplots() 

#ax.plot(range(1, 11), layer1, color = rainbow[6],  linewidth=4)
ax.plot(range(1, 11), layer2, color = rainbow[5],  linewidth=4,)
ax.plot(range(1, 11), layer3, color = rainbow[3],  linewidth=4,)
ax.plot(range(1, 11), layer4, color = rainbow[1], linewidth=4,)
ax.plot(range(1, 11), layer5, color = rainbow[0],  linewidth=4,)

ax.set_xlabel('Epoch', fontname="Arial", fontsize = 20)
ax.set_ylabel('Cross-Entropy', fontname="Arial", fontsize = 20)
ax.set_title('Testing Loss', fontname="Arial", fontsize = 25, fontweight="bold")



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.ylim(.8, 1.6)
    
plt.show()

# %%
layer2 = np.load('first_layer_activations_train2.npy');
layer3 = np.load('first_layer_activations_train3.npy');
layer4 = np.load('first_layer_activations_train4.npy');
layer5 = np.load('first_layer_activations_train5.npy');

# %%
layer2 = layer2.flatten()
layer3 = layer3.flatten()
layer4 = layer4.flatten()
layer5 = layer5.flatten()

# %%
from sklearn.neighbors import KernelDensity
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric.kernel_density import KDEMultivariate



def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)

# %%
 
x_grid = np.linspace(-4.5, 3.5, 1000)
bandwidth = .05


fig, ax = plt.subplots() 

plt.plot(x_grid, kde_sklearn(layer2, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, color = rainbow[5])


plt.plot(x_grid, kde_sklearn(layer3, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, color = rainbow[3])

plt.plot(x_grid, kde_sklearn(layer4, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, color = rainbow[1])

plt.plot(x_grid, kde_sklearn(layer5, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, color = rainbow[0])


ax.set_xlabel('Unit Activations', fontname="Arial", fontsize = 20)
ax.set_ylabel('Proportion', fontname="Arial", fontsize = 20)
ax.set_title('Activations', fontname="Arial", fontsize = 25, fontweight="bold")



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.show()

# %%
def average_curvature_histogram(layer_weights, num_bins=50):
    curvatures = []

    for layer in layer_weights:
        # Flatten the layer weights
        #flattened_weights = layer.view(-1).cpu().numpy()

        # Calculate the histogram
        hist, bin_edges = np.histogram(layer, bins=num_bins)

        # Calculate the curvature for each bin
        curvature = np.diff(np.diff(hist))

        # Take the absolute value of the curvature
        curvature = np.abs(curvature)

        # Average curvature
        average_curvature = np.max(curvature)
        curvatures.append(average_curvature)

    return curvatures

# %%
curvatures = average_curvature_histogram([layer2, layer3, layer4, layer5])



layers = ['Layer 2', 'Layer 3', 'Layer 4', 'Layer 5']
plt.bar(layers, curvatures, color='blue')
plt.xlabel('Layers')
plt.ylabel('Average Curvature of Histogram')
plt.title('Average Curvature of Histogram for Each Layer')
plt.show()

# %%
from scipy.stats import kurtosis
def calculate_histogram_kurtosis(layer):
    hist, bin_edges = np.histogram(layer.flatten(), bins=50)
    return kurtosis(hist)

# Arrays to analyze
layers = [layer2, layer3, layer4, layer5]

# Calculate kurtosis for each layer
kurtosis_values = [calculate_histogram_kurtosis(layer) for layer in layers]

fig, ax = plt.subplots() 

# Bar plot

ax.set_xlabel('Depth', fontname="Arial", fontsize = 20)
ax.set_ylabel('Kurtosis', fontname="Arial", fontsize = 20)
ax.set_title('Filter Selectivity', fontname="Arial", fontsize = 25, fontweight="bold")


colors = [5, 3, 1, 0];
layers = ['2', '3', '4', '5']

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
bars = ax.bar(layers, kurtosis_values, color='blue')
for i, bar in enumerate(bars):
    bar.set_color(rainbow[colors[i]])


# Set the font name for axis tick labels to be Comic Sans
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load activations for each layer
layer2 = np.load('first_layer_activations_train2.npy')
layer3 = np.load('first_layer_activations_train3.npy')
layer4 = np.load('first_layer_activations_train4.npy')
layer5 = np.load('first_layer_activations_train5.npy')

# Create subplots for each layer
fig, axs = plt.subplots(4, 6, figsize=(12, 8))

# Iterate through each layer and filter
for i, layer in enumerate([layer2, layer3, layer4, layer5]):
    for j in range(6):
        # Display the activation for the first stimulus
        axs[i, j].imshow(layer[1, j], cmap='gray')  # Use 'gray' colormap for grayscale
        axs[i, j].set_title('')  # Remove title

# Set common labels and title
for ax in axs.flat:
    ax.set(xlabel='', ylabel='')

fig.suptitle('')  # Remove title

# Adjust layout for better visualization
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Remove all axis ticks and labels
for ax in axs.flat:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# Show the plot
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np


import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
# Load CIFAR-10 dataset for color images
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)


# Display the first 10 images from the training set
num_images = 10
classes = trainset.classes

def imshow(img):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get a batch of training data
dataiter = iter(trainloader)
images, labels = dataiter.next()

# Show images
imshow(torchvision.utils.make_grid(images[:num_images]))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
